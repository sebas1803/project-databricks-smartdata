# %% [markdown]
# # Widgets

# %%
dbutils.widgets.removeAll()

# %% [markdown]
# %sql
# CREATE WIDGET TEXT storageName DEFAULT "adlssmartdata0812";

# %% [markdown]
# # External locations

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-raw`
URL 'abfss://raw@${storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación de datasets crudos (e-commerce y supermercado)';

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-bronze`
URL 'abfss://bronze@${storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación externa para tablas Bronze';

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-silver`
URL 'abfss://silver@${storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación externa para tablas Silver';

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-gold`
URL 'abfss://gold@${storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación externa para tablas Gold';

# %% [markdown]
# # Catalog & Schemas

# %%
# %sql
CREATE CATALOG IF NOT EXISTS retail_ecommerce_prod;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS retail_ecommerce_prod.bronze;
CREATE SCHEMA IF NOT EXISTS retail_ecommerce_prod.silver;
CREATE SCHEMA IF NOT EXISTS retail_ecommerce_prod.gold;

# %%
# %sql
SHOW SCHEMAS IN retail_ecommerce_prod;
